# %% [markdown]
# <a href="https://colab.research.google.com/github/topalak/Breast-Cancer-Detection/blob/main/regression_of_used_cars_price_playground_s4e9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %%
train.tail()
# Out:
#             id          brand                     model  model_year  milage  \
# 188528  188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188531  188531           Audi          S5 3.0T Prestige        2022   13895
# 188532  188532        Porsche                Macan Base        2016   59500
#
#        fuel_type                                         engine  \
# 188528  Gasoline   420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188529  Gasoline  385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188530  Gasoline   469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188531  Gasoline                                           3.0L
# 188532  Gasoline   252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                           transmission                    ext_col int_col  \
# ...

# %%
test.head()
# Out:
#        id brand                 model  model_year  milage fuel_type  \
# 0  188533  Land        Rover LR2 Base        2015   98000  Gasoline
# 1  188534  Land     Rover Defender SE        2020    9142    Hybrid
# 2  188535  Ford    Expedition Limited        2022   28121  Gasoline
# 3  188536  Audi         A6 2.0T Sport        2016   61258  Gasoline
# 4  188537  Audi  A6 2.0T Premium Plus        2018   59000  Gasoline
#
#                                               engine        transmission  \
# 0       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 1  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 2                    3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 3                                     2.0 Liter TFSI           Automatic
# 4       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel                 A/T
#
#            ext_col int_col       accident clean_title
# 0            White   Beige  None reported         Yes
# ...

# %%
print(train['fuel_type'].unique())
# Out:
# ['Gasoline' 'E85 Flex Fuel' nan 'Hybrid' 'Diesel' 'Plug-In Hybrid' '–'
#  'not supported']

# %%
#train['fuel_type'] = train['fuel_type'].fillna('Electricity')
train['fuel_type'].replace('not supported', 'Electric', inplace = True)
train['fuel_type'].replace('–', 'Electric', inplace = True)
train['fuel_type'].replace('nan', 'Electric', inplace = True)

# %%
train['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline          165940
# Hybrid              6832
# E85 Flex Fuel       5406
# Diesel              3955
# Electric             796
# Plug-In Hybrid       521
# Name: count, dtype: int64

# %%
#e85 leri getir|

# %%
#import re (beginners kaggle notebook ta eleman yapmis orada kaldin incele)

# %%
null_rows_with_values = train[train['fuel_type'].isna()]

# %%
null_rows_with_values.sample(5)
# Out:
#             id   brand                    model  model_year  milage fuel_type  \
# 46223    46223    Audi          e-tron Prestige        2019     500       NaN
# 178287  178287   Tesla  Model X Long Range Plus        2020   65441       NaN
# 176409  176409   Tesla             Model S 100D        2017   75000       NaN
# 101240  101240   Tesla       Model Y Long Range        2021   30900       NaN
# 177699  177699  Rivian    R1S Adventure Package        2023     299       NaN
#
#                                              engine transmission ext_col  \
# 46223   355.0HP Electric Motor Electric Fuel System  1-Speed A/T   White
# 178287  534.0HP Electric Motor Electric Fuel System          A/T  Silver
# 176409  518.0HP Electric Motor Electric Fuel System          A/T    Gray
# 101240  425.0HP Electric Motor Electric Fuel System          A/T   Black
# 177699  835.0HP Electric Motor Electric Fuel System  1-Speed A/T   Black
#
#        int_col       accident clean_title  price
# ...

# %% [markdown]
# ** i've tried for couple times and i saw every electric motor model looks nan in df **

# %%
train.sample(20)
# Out:
#             id          brand                    model  model_year  milage  \
# 115673  115673           Ford                F-150 XLT        2018   65441
# 168735  168735           Ford     Mustang Shelby GT500        2016   53000
# 26012    26012           Jeep        Gladiator Sport S        2022   23000
# 127198  127198       Cadillac        Escalade ESV Base        2022   16754
# 5162      5162         Jaguar       F-PACE 35t Premium        2021   23600
# 108665  108665        Porsche           911 Carrera 4S        2016   22000
# 94941    94941  Mercedes-Benz     S-Class S 550 4MATIC        2022    1750
# 131378  131378    Lamborghini    Huracan Tecnica Coupe        2023    1385
# 21963    21963            Kia               Sorento LX        2018   36602
# 145211  145211          Honda               Pilot EX-L        2012  118206
# 147685  147685            BMW            M550 i xDrive        2018    9100
# ...

# %%
'''beginner olanda bu kisminda kaldin re kutuphanesini arastirmaya devam et
# Out:
#   File "<ipython-input-168-3a6988932929>", line 1
#     '''beginner olanda bu kisminda kaldin re kutuphanesini arastirmaya devam et
#     ^
# SyntaxError: incomplete input

# %%
# Define a function to extract engine attributes
def extract_engine_attributes(engine_str):
    horsepower = re.search(r'(\d+\.\d+)HP|\d+\.\d+', engine_str)
    displacement = re.search(r'(\d+\.\d+)L|(\d+\.\d+) Liter', engine_str)
    return horsepower.group(1) if horsepower else '',\
           displacement.group(1) if displacement else ''

# Apply the function to create new columns
train_data[['horsepower', 'engine_displacement']] = train_data['engine'].apply(extract_engine_attributes).apply(pd.Series)
test_data[['horsepower', 'engine_displacement']] = test_data['engine'].apply(extract_engine_attributes).apply(pd.Series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-5423db8f54cb> in <cell line: 9>()
#       7
#       8 # Apply the function to create new columns
# ----> 9 train_data[['horsepower', 'engine_displacement']] = train_data['engine'].apply(extract_engine_attributes).apply(pd.Series)
#      10 test_data[['horsepower', 'engine_displacement']] = test_data['engine'].apply(extract_engine_attributes).apply(pd.Series)
#
# NameError: name 'train_data' is not defined
